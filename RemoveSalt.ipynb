# %%
from rdkit import Chem
from rdkit.Chem import SaltRemover
from rdkit.Chem.Draw import IPythonConsole

# %%
mols = [Chem.MolFromSmiles(i) for i in ['CN(C)C.Cl.Cl.Br', '[Na+].CN(C1=NC=CC=C1CNC1=NC(NC2=CC=C(C=C2)C([O-])=O)=NC=C1C(F)(F)F)S(C)(=O)=O']]
mols

# %%
m = Chem.MolFromSmiles('[Na+].CN(C1=NC=CC=C1CNC1=NC(NC2=CC=C(C=C2)C([O-])=O)=NC=C1C(F)(F)F)S(C)(=O)=O')
m
